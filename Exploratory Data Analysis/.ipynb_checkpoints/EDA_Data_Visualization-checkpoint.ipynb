# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data = pd.read_csv('housing_data.csv')
housing_data.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL         65.0     8450   Pave   NaN      Reg
# 1           1       SC20       RL         80.0     9600   Pave   NaN      Reg
# 2           2       SC60       RL         68.0    11250   Pave   NaN      IR1
# 3           3       SC70       RL         60.0     9550   Pave   NaN      IR1
# 4           4       SC60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
housing_data.drop('Unnamed: 0', axis=1, inplace=True)
housing_data
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          SC60       RL         65.0     8450   Pave   NaN      Reg
# 1          SC20       RL         80.0     9600   Pave   NaN      Reg
# 2          SC60       RL         68.0    11250   Pave   NaN      IR1
# 3          SC70       RL         60.0     9550   Pave   NaN      IR1
# 4          SC60       RL         84.0    14260   Pave   NaN      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1455       SC60       RL         62.0     7917   Pave   NaN      Reg
# 1456       SC20       RL         85.0    13175   Pave   NaN      Reg
# 1457       SC70       RL         66.0     9042   Pave   NaN      Reg
# 1458       SC20       RL         68.0     9717   Pave   NaN      Reg
# 1459       SC20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %% [markdown]
# #### Check for any missing Values

# %%
housing_data.shape
# Out:
# (1460, 80)

# %%
housing_data['Alley'].mode()
# Out:
# 0    Grvl
# Name: Alley, dtype: object

# %%
housing_data['Alley'].fillna('Grvl', inplace = True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3692\662871250.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   housing_data['Alley'].fillna('Grvl', inplace = True)

# %% [markdown]
# ## Univariate Analysis
# * Univariate analysis is the simplest form of analysis
# * Only one variable is used in visualization
# * It doesn't deal with relationship plots. It takes data, summarize the data, pattern analysis, trend analysis in data.
# * Univariate analysis can be implemented on **numerical data** or **categorical data**

# %%
# Selects attributes with the specified data type
df_numerical = housing_data.select_dtypes(include = ['number'])
df_numerical
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0            65.0     8450            7            5       2003          2003
# 1            80.0     9600            6            8       1976          1976
# 2            68.0    11250            7            5       2001          2002
# 3            60.0     9550            7            5       1915          1970
# 4            84.0    14260            8            5       2000          2000
# ...           ...      ...          ...          ...        ...           ...
# 1455         62.0     7917            6            5       1999          2000
# 1456         85.0    13175            6            6       1978          1988
# 1457         66.0     9042            7            9       1941          2006
# 1458         68.0     9717            5            6       1950          1996
# 1459         75.0     9937            5            6       1965          1965
#
# ...

# %%
df_categorical = housing_data.select_dtypes(include = ['O'])
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 45 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   Street         1460 non-null   object
#  3   Alley          1460 non-null   object
#  4   LotShape       1460 non-null   object
#  5   LandContour    1460 non-null   object
#  6   Utilities      1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   LandSlope      1460 non-null   object
#  9   Neighborhood   1460 non-null   object
#  10  Condition1     1460 non-null   object
#  11  Condition2     1460 non-null   object
#  12  BldgType       1460 non-null   object
#  13  HouseStyle     1460 non-null   object
#  14  RoofStyle      1460 non-null   object
#  15  RoofMatl       1460 non-null   object
#  16  Exterior1st    1460 non-null   object
# ...

# %% [markdown]
# ### 1. Line Plot
# * Univariate (single variable) - Trend Analysis
# * Bivariate (two variable) - Relationship Plot
# * Implemented for Trend Analysis and Trend Behaviour

# %%
# Inbuilt Pandas Function to Plot Graphs using - plot()
df_numerical['SalePrice'].plot(kind = 'line')
# Out:
# <Axes: >

# %%
plt.figure(figsize = [5, 5])
plt.style.use('ggplot')
plt.plot(df_numerical['SalePrice'].sort_values(ascending = True).unique(), color = 'orangered')
plt.xlabel("Index")
plt.ylabel("Sales Price")
plt.title("Sales Price Trends")
plt.show()

# %% [markdown]
# ### 2. Bar Plot
# * Univariate or Bivariate Plot
# * Bar Chart are used with categorical dataset
# * They are used to display counts of uique values for categorical type
# * Heigh of bars indicate the count for each category

# %%
df_categorical
# Out:
#      MSSubClass MSZoning Street Alley LotShape LandContour Utilities  \
# 0          SC60       RL   Pave  Grvl      Reg         Lvl    AllPub
# 1          SC20       RL   Pave  Grvl      Reg         Lvl    AllPub
# 2          SC60       RL   Pave  Grvl      IR1         Lvl    AllPub
# 3          SC70       RL   Pave  Grvl      IR1         Lvl    AllPub
# 4          SC60       RL   Pave  Grvl      IR1         Lvl    AllPub
# ...         ...      ...    ...   ...      ...         ...       ...
# 1455       SC60       RL   Pave  Grvl      Reg         Lvl    AllPub
# 1456       SC20       RL   Pave  Grvl      Reg         Lvl    AllPub
# 1457       SC70       RL   Pave  Grvl      Reg         Lvl    AllPub
# 1458       SC20       RL   Pave  Grvl      Reg         Lvl    AllPub
# 1459       SC20       RL   Pave  Grvl      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageFinish GarageQual GarageCond  \
# ...

# %%
df_categorical['MoSold'].value_counts().values
plt.figure(figsize = [7, 8])
plt.xlabel("Month")
plt.ylabel("Sales per Month")
plt.title("Monthly Sales Price Trends", size = 12)
plt.bar(df_categorical['MoSold'].value_counts().index, height = df_categorical['MoSold'].value_counts().values)
# Out:
# <BarContainer object of 12 artists>

# %%
df_categorical['MoSold'].value_counts().plot(kind = 'bar', color = 'green', figsize = [4, 3])
# Out:
# <Axes: xlabel='MoSold'>

# %% [markdown]
# ### 3. Histogram
# * Univariate Analysis - Apply on continous data.
# * Frequency of Data in range
# * Study of Spread / Data Distribution

# %%
df_numerical
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0            65.0     8450            7            5       2003          2003
# 1            80.0     9600            6            8       1976          1976
# 2            68.0    11250            7            5       2001          2002
# 3            60.0     9550            7            5       1915          1970
# 4            84.0    14260            8            5       2000          2000
# ...           ...      ...          ...          ...        ...           ...
# 1455         62.0     7917            6            5       1999          2000
# 1456         85.0    13175            6            6       1978          1988
# 1457         66.0     9042            7            9       1941          2006
# 1458         68.0     9717            5            6       1950          1996
# 1459         75.0     9937            5            6       1965          1965
#
# ...

# %%
# bins : it is used to specify the distribution of the data range between which the frequency will be counted
plt.style.use('ggplot')
plt.figure(figsize=[6, 5])
plt.hist(df_numerical['SalePrice'], bins = 30)
# Out:
# (array([ 11.,  38.,  99., 232., 273., 218., 176., 104.,  93.,  58.,  42.,
#          35.,  24.,  10.,  17.,   8.,   7.,   4.,   2.,   1.,   1.,   2.,
#           1.,   0.,   2.,   0.,   0.,   0.,   0.,   2.]),
#  array([ 34900.        ,  58903.33333333,  82906.66666667, 106910.        ,
#         130913.33333333, 154916.66666667, 178920.        , 202923.33333333,
#         226926.66666667, 250930.        , 274933.33333333, 298936.66666667,
#         322940.        , 346943.33333333, 370946.66666667, 394950.        ,
#         418953.33333333, 442956.66666667, 466960.        , 490963.33333333,
#         514966.66666667, 538970.        , 562973.33333333, 586976.66666667,
#         610980.        , 634983.33333333, 658986.66666667, 682990.        ,
#         706993.33333333, 730996.66666667, 755000.        ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ### 4. Subplots
# * Here one plot will be splitted into multiple plots
# * Each index postion will be occupied by one plot

# %%
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
df_categorical
df_categorical['LandSlope'].unique()
# Out:
# array(['Gtl', 'Mod', 'Sev'], dtype=object)

# %%
df4 = housing_data.query("LandSlope == 'Gtl'")
df4[['SalePrice']]
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1382 rows x 1 columns]

# %%
plt.subplot(2, 2, 1)
plt.hist(housing_data[housing_data['LandSlope'] == 'Gtl']['SalePrice'], bins = 15, color='b', alpha=0.5)

plt.subplot(2, 2, 2)
plt.hist(housing_data[housing_data['LandSlope'] == 'Mod']['SalePrice'], bins = 15, color='r', alpha=0.5)

plt.subplot(2, 2, 3)
plt.hist(housing_data[housing_data['LandSlope'] == 'Sev']['SalePrice'], bins = 15, color='g', alpha=0.5)
# Out:
# (array([1., 0., 1., 2., 1., 2., 0., 0., 2., 1., 1., 1., 0., 0., 1.]),
#  array([ 61000.        ,  81933.33333333, 102866.66666667, 123800.        ,
#         144733.33333333, 165666.66666667, 186600.        , 207533.33333333,
#         228466.66666667, 249400.        , 270333.33333333, 291266.66666667,
#         312200.        , 333133.33333333, 354066.66666667, 375000.        ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# ### 5. Scatter Plot
# * Indicates relationship plot or correlation between two numerical columns

# %%
plt.figure(figsize = [5, 4])
plt.scatter(df_numerical[df_numerical['LotArea'] < 60000]['LotArea'], 
            df_numerical[df_numerical['LotArea'] < 60000]['SalePrice'])
plt.xlabel("Lot Area")
plt.ylabel("Sales Price")
plt.title("Scatter Plot - Relationship b/w LotArea and SalePrice", size = 10)
plt.show()

# %% [markdown]
# ### 6. Seaborn Plot

# %%
sns.scatterplot(x = df_numerical[df_numerical['LotArea'] < 60000]['LotArea'], 
            y =df_numerical[df_numerical['LotArea'] < 60000]['SalePrice'],
            hue = df_categorical['GarageType'], s = 50)
plt.show()

# %%
sns.scatterplot(x = df_numerical['GarageArea'], 
            y =df_numerical['SalePrice'],
            hue = df_categorical['GarageType'], s = 50, marker='*')
# s = size of bubble
# marker = type of bubble ('s', '^', '>', '<', '*', 'd', 'o', '+', , '-')
# alpha = transparency of each bubble
plt.show()

# %% [markdown]
# ### 7. Pie-Chart
# * Freuency Distribution Plot

# %%
df_categorical['LotConfig'].value_counts()
# Out:
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64

# %%
plt.pie(df_categorical['LotConfig'].value_counts(), autopct='%0.2f%%', 
        labels = ['Inside', 'Corner', 'CulDSac', 'FR2', 'FR3'])
plt.legend(loc =1)
plt.show()

# %% [markdown]
# ### 8. Distribution Plot / Kernel Density Estimator (KDE) Plot
# * Shows historgram + density plot to display distribution of numerical continous data.

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df_numerical[df_numerical['GarageArea'] > 0]['GarageArea'], hist=False, color = 'g')
plt.show()

# %% [markdown]
# ### 9. Box Plot
# * Box Plot is dividided into a two parts.
# * It contains 5 important aspects : min val, Q1(25%), Q2(50%), Q3(75%), Max val
# * min val = Q1 - 1.5 x IQR
# * max val = Q3 + 1.5 x IQR (Inter Quartile Range)
# * ![image.png](attachment:95a1af0c-aa1f-422f-9c2f-9cd13b9177d0.png)![image.png](attachment:334d3ee7-0c7c-448d-b25c-e55c88c20937.png)

# %%
plt.figure(figsize=[10,4])
sns.boxplot(df_numerical[df_numerical['GarageArea']>0]['GarageArea'], orient = 'h')
plt.show()

# %% [markdown]
# ### 10. Violin Plot
# * Multivariate plot

# %%
sns.violinplot(df_numerical[df_numerical['GarageArea']>0]['GarageArea'])
# Out:
# <Axes: ylabel='GarageArea'>

# %%
sns.boxplot(x = 'LotConfig', y = 'SalePrice', data = housing_data, hue = 'LotConfig', palette = 'viridis')
# Out:
# <Axes: xlabel='LotConfig', ylabel='SalePrice'>

# %%
sns.violinplot(x = 'LotConfig', y = 'SalePrice', data = housing_data, hue = 'LotConfig', palette = 'Set2')
# Out:
# <Axes: xlabel='LotConfig', ylabel='SalePrice'>

# %% [markdown]
# ### 11. Heatmap - Multivariate Plot

# %%
df_numerical.corr()['SalePrice'].sort_values()
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# OverallCond     -0.077856
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# MiscVal         -0.021190
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# 3SsnPorch        0.044584
# PoolArea         0.092404
# ScreenPorch      0.111447
# BedroomAbvGr     0.168213
# LotFrontage      0.209624
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# MasVnrArea       0.472614
# GarageYrBlt      0.486362
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# GrLivArea        0.708624
# OverallQual      0.790982
# SalePrice        1.000000
# ...

# %%
sns.heatmap(df_numerical.corr()[['SalePrice']], annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=[25,20])
sns.heatmap(df_numerical.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### 12. Area Plot

# %%
housing_data.plot(kind = 'area', stacked = True, alpha = 0.7)
# Out:
# <Axes: >

# %%
housing_data[['YrSold','LotArea']].plot(kind = 'area', stacked = True, alpha = 0.7)
# Out:
# <Axes: >

# %%
housing_data
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          SC60       RL         65.0     8450   Pave  Grvl      Reg
# 1          SC20       RL         80.0     9600   Pave  Grvl      Reg
# 2          SC60       RL         68.0    11250   Pave  Grvl      IR1
# 3          SC70       RL         60.0     9550   Pave  Grvl      IR1
# 4          SC60       RL         84.0    14260   Pave  Grvl      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1455       SC60       RL         62.0     7917   Pave  Grvl      Reg
# 1456       SC20       RL         85.0    13175   Pave  Grvl      Reg
# 1457       SC70       RL         66.0     9042   Pave  Grvl      Reg
# 1458       SC20       RL         68.0     9717   Pave  Grvl      Reg
# 1459       SC20       RL         75.0     9937   Pave  Grvl      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...
